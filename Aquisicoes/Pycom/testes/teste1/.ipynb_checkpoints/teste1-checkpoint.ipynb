# %% [markdown]
# # Aquisição 1 - Pycom

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats.stats import pearsonr

# %% [markdown]
# #### As matrizes devem ser importadas com TODOS os dados que estiverem no CSV. O processamento será feito aqui mesmo.

# %%
matrizGateway = [["0","-36"],["1","-36"],["5","-38"],["9","-42"],["13","-43"],["17","-42"],["21","-59"],["23","-79"],["29","-53"],["33","-63"],["37","-63"],["39","-47"],["43","-43"],["48","-41"],["52","-48"],["56","-31"],["60","-36"],["64","-43"],["68","-35"],["72","-57"],["76","-43"],["80","-49"],["85","-60"],["89","-49"],["93","-58"],["97","-49"],["101","-45"],["105","-61"],["109","-69"],["113","-53"],["117","-55"],["121","-75"],["125","-63"],["130","-65"],["134","-59"],["138","-64"],["142","-61"],["146","-67"],["150","-72"],["154","-69"],["158","-78"],["162","-75"],["166","-66"],["170","-56"],["175","-57"],["179","-73"],["183","-59"],["187","-53"],["191","-53"],["195","-58"],["199","-54"],["203","-75"],["207","-57"],["212","-76"],["216","-78"],["221","-79"],["228","-65"],["232","-51"],["236","-76"],["240","-71"],["244","-69"],["248","-76"],["252","-73"],["256","-62"],["261","-65"],["265","-67"],["269","-73"],["273","-76"],["277","-65"],["281","-57"],["285","-48"],["289","-51"],["293","-36"],["298","-36"],["302","-20"],["306","-30"]]
matrizENPreliminar = [["0","Inicio"],["1","Sem resposta"],["2","-44"],["3","-44"],["4","-45"],["5","Sem resposta"],["6","-57"],["7","-49"],["8","-53"],["9","Sem resposta"],["10","-49"],["11","-54"],["12","-52"],["13","Sem resposta"],["14","-49"],["15","-56"],["16","-54"],["17","Sem resposta"],["18","-49"],["19","-47"],["20","-51"],["21","Sem resposta"],["23","Sem resposta"],["24","-51"],["25","-47"],["26","-48"],["27","-45"],["28","-46"],["29","Sem resposta"],["30","-47"],["31","-48"],["32","-49"],["33","Sem resposta"],["34","-49"],["35","-53"],["36","-46"],["37","Sem resposta"],["38","-53"],["39","Sem resposta"],["40","-52"],["41","-51"],["42","-50"],["43","Sem resposta"],["44","-44"],["45","-49"],["46","-44"],["47","-48"],["48","Sem resposta"],["49","-46"],["50","-45"],["51","-50"],["52","Sem resposta"],["53","-42"],["54","-43"],["55","-42"],["56","Sem resposta"],["57","-40"],["58","-42"],["59","-41"],["60","Sem resposta"],["61","-31"],["62","-32"],["63","-33"],["64","Sem resposta"],["65","-47"],["66","-40"],["67","-44"],["68","Sem resposta"],["69","-44"],["70","-51"],["71","-48"],["72","Sem resposta"],["73","-50"],["74","-50"],["75","-51"],["76","Sem resposta"],["77","-48"],["78","-52"],["79","-59"],["80","Sem resposta"],["81","-62"],["82","-61"],["83","-56"],["84","-60"],["85","Sem resposta"],["86","-59"],["87","-66"],["88","-62"],["89","Sem resposta"],["90","-67"],["91","-73"],["92","-64"],["93","Sem resposta"],["94","-64"],["95","-59"],["96","-58"],["97","Sem resposta"],["98","-53"],["99","-50"],["100","-47"],["101","Sem resposta"],["102","-50"],["103","-49"],["104","-47"],["105","Sem resposta"],["106","-64"],["107","-58"],["108","-56"],["109","Sem resposta"],["110","-62"],["111","-56"],["112","-56"],["113","Sem resposta"],["114","-54"],["115","-73"],["116","-57"],["117","Sem resposta"],["118","-56"],["119","-82"],["120","-65"],["121","Sem resposta"],["122","-73"],["123","-75"],["124","-85"],["125","Sem resposta"],["126","-71"],["127","-62"],["128","-63"],["129","-73"],["130","Sem resposta"],["131","-79"],["132","-75"],["133","-66"],["134","Sem resposta"],["135","-66"],["136","-64"],["137","-71"],["138","Sem resposta"],["139","-61"],["140","-82"],["141","-71"],["142","Sem resposta"],["143","-70"],["144","-64"],["145","-68"],["146","Sem resposta"],["147","-68"],["148","-62"],["149","-73"],["150","Sem resposta"],["151","-69"],["152","-66"],["153","-69"],["154","Sem resposta"],["155","-80"],["156","-83"],["157","-81"],["158","Sem resposta"],["159","-90"],["160","-84"],["161","-80"],["162","Sem resposta"],["163","-74"],["164","-76"],["165","-85"],["166","Sem resposta"],["167","-82"],["168","-75"],["169","-67"],["170","Sem resposta"],["171","-67"],["172","-68"],["173","-66"],["174","-67"],["175","Sem resposta"],["176","-60"],["177","-60"],["178","-64"],["179","Sem resposta"],["180","-58"],["181","-53"],["182","-50"],["183","Sem resposta"],["184","-46"],["185","-50"],["186","-43"],["187","Sem resposta"],["188","-60"],["189","-52"],["190","-53"],["191","Sem resposta"],["192","-63"],["193","-59"],["194","-57"],["195","Sem resposta"],["196","-58"],["197","-57"],["198","-66"],["199","Sem resposta"],["200","-64"],["201","-77"],["202","-65"],["203","Sem resposta"],["204","-71"],["205","-65"],["206","-62"],["207","Sem resposta"],["208","-71"],["209","-64"],["210","-75"],["211","-69"],["212","Sem resposta"],["213","-81"],["214","-77"],["215","-76"],["216","Sem resposta"],["217","-78"],["218","-76"],["219","-81"],["221","Sem resposta"],["222","-74"],["223","-79"],["224","-76"],["225","-68"],["226","-73"],["227","-83"],["228","Sem resposta"],["229","-64"],["230","-65"],["231","-53"],["232","Sem resposta"],["233","-59"],["234","-70"],["235","-66"],["236","Sem resposta"],["237","-71"],["238","-79"],["239","-73"],["240","Sem resposta"],["241","-78"],["242","-80"],["243","-78"],["244","Sem resposta"],["245","-69"],["246","-78"],["247","-87"],["248","Sem resposta"],["249","-83"],["250","-77"],["251","-75"],["252","Sem resposta"],["253","-76"],["254","-75"],["255","-70"],["256","Sem resposta"],["257","-71"],["258","-67"],["259","-66"],["260","-66"],["261","Sem resposta"],["262","-65"],["263","-60"],["264","-69"],["265","Sem resposta"],["266","-63"],["267","-63"],["268","-69"],["269","Sem resposta"],["270","-73"],["271","-62"],["272","-63"],["273","Sem resposta"],["274","-67"],["275","-58"],["276","-61"],["277","Sem resposta"],["278","-73"],["279","-60"],["280","-67"],["281","Sem resposta"],["282","-60"],["283","-60"],["284","-52"],["285","Sem resposta"],["286","-61"],["287","-54"],["288","-54"],["289","Sem resposta"],["290","-47"],["291","-48"],["292","-58"],["293","Sem resposta"],["294","-49"],["295","-41"],["296","-44"],["297","-43"],["298","Sem resposta"],["299","-34"],["300","-35"],["301","-40"]]

# %% [markdown]
# #### Filtrando os dados:

# %% [markdown]
# A matriz do End Node veio muito maior que a do Gateway. Como se sabe, o frame count **n** do End Node corresponde ao frame count __n+1__ do Gateway. Então o código abaixo percorre a matriz do End Node e remove tudo que for texto ("Sem resposta" ou "inicio") e tudo que não for um frame count igual a um frame count +1 do gateway. Ainda pode ser que um determinado frame count +1 não exista na matriz do End Node, talvez por perda de pacote. Então alguns dados da matriz do gateway também deverão ser excluidos.

# %%
# Criando a matriz final do end node e os indexes que deverão ser excluidos da matriz do gateway
matrizEndNode = []
indexesExcluir = []

# Percorrendo a matriz do gateway
for index, vGateway in enumerate(matrizGateway):
    # Guardando o frame count atual e setando a variavel que vai dizer 
    # se existe o frame count +1 na matriz do endnode
    fCntAtual = vGateway[0]
    existe = 0
    
    # Percorrendo a matriz do endnode
    for vEndNode in matrizENPreliminar:
        # Se tiver um frame count +1 e o dado for um inteiro, então existe
        if vEndNode[0] == str(int(fCntAtual) + 1):
            try:
                inteiro = int(vEndNode[1])
                matrizEndNode.append(vEndNode)
                existe = 1
                break
            except:
                pass         
            
    # Se no final não existir, então é um index do gateway que deverá ser excluido
    if existe == 0:
        indexesExcluir.append(index)

# Removendo os indexes do gateway que não tem um correspondente frame count +1 no endnode
for i in reversed(indexesExcluir):
    del matrizGateway[i]
        
# Removendo os ultimos dados do gateway até o tamanho das duas matrizes ser igual
while len(matrizEndNode) != len(matrizGateway):
    matrizGateway = matrizGateway[:-1]

# %%
# Pegando apenas os dados de rssi e transformando em inteiros
rssiGateway = [int(dado[1]) for dado in matrizGateway]
rssiGateway = np.array(rssiGateway)

rssiEndNode = [int(dado[1]) for dado in matrizEndNode]
rssiEndNode = np.array(rssiEndNode)

# %% [markdown]
# #### Plotando

# %%
#DEFININDO ALGUNS PARÂMETROS DO GRÁFICO
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
params = {'figure.figsize': [25, 4], 
          'axes.labelsize': 14,
          'axes.titlesize':18, 
          'font.size': 12,
          'legend.fontsize': 12, 
          'xtick.labelsize': 10, 
          'ytick.labelsize': 10,
          'axes.axisbelow': True
         }

plt.rcParams.update(params)

# %%
# PLOTANDO
plt.scatter(range(1, len(matrizGateway) + 1), rssiGateway, s=50, alpha=0.7, label="ENDNODE PARA O GATEWAY")
plt.scatter(range(1, len(matrizGateway) + 1), rssiEndNode, s=50, alpha=0.7, label="GATEWAY PARA O ENDNODE")

# PARAMETROS ADICIONAIS
plt.legend()
plt.title("Comparação RSSI no oitavo andar")
plt.xlabel("Pacote")
plt.ylabel("Rssi")
plt.ylim(-90,0)
plt.grid(True, axis='y', alpha=0.7)

# SALVANDO
plt.savefig('graficoRSSI.pdf', format='pdf', bbox_inches = 'tight')

# EXIBINDO
plt.plot()
# Out:
# []

# %% [markdown]
# #### Correlação

# %%
print("Correlação:", pearsonr(rssiEndNode, rssiGateway)[0])
# Out:
# Correlação: 0.7886862663662938
