# %%
import matplotlib.pyplot as plt
from numpy import array

# %%
rssiGateway = array([-31, -33, -33, -51, -39, -48, -56, -55, -67, -58, -69, -75, -70, -72, -76, -67, -78, -76, -78, -80, -83, -69, -64, -65, -70, -70, -77, -76, -67, -70, -71, -76, -67, -78, -60, -60, -76, -69, -61, -59, -53, -55, -45, -51, -55, -70, -65, -66, -67, -65, -63, -54, -54, -49, -51, -47, -48, -47, -43, -57, -45, -48, -54, -47, -41, -42, -47, -37, -30, -33, -35, -34, -33, -31, -31])
rssiEndNode = array([-39, -36, -28, -46, -53, -47, -58, -56, -66, -73, -66, -74, -68, -70, -73, -73, -80, -70, -79, -84, -73, -70, -67, -69, -74, -64, -68, -74, -64, -71, -79, -79, -77, -74, -70, -60, -73, -67, -61, -59, -48, -53, -45, -47, -50, -66, -64, -65, -86, -61, -64, -67, -59, -58, -52, -52, -43, -48, -49, -51, -40, -61, -48, -64, -47, -45, -43, -50, -40, -39, -34, -48, -36, -37, -36])
pacote = range(0,len(rssiGateway))

# %%
#DEFININDO ALGUNS PARÂMETROS DO GRÁFICO
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
params = {'figure.figsize': [8, 4], 
          'axes.labelsize': 14,
          'axes.titlesize':18, 
          'font.size': 12,
          'legend.fontsize': 12, 
          'xtick.labelsize': 10, 
          'ytick.labelsize': 10,
          'axes.axisbelow': True
         }

plt.rcParams.update(params)

# %%
# PLOTANDO
plt.scatter(, rssiGateway, s=100, alpha=0.7, label="ENDNODE PARA O GATEWAY")
plt.scatter(contEndNode, rssiEndNode, s=100, alpha=0.7, label="GATEWAY PARA O ENDNODE")

# PARAMETROS ADICIONAIS
plt.legend()
plt.title("Comparação RSSI no oitavo andar")
plt.xlabel("Contador")
plt.ylabel("Rssi")
plt.ylim(-90,0)
plt.grid(True, axis='y', alpha=0.7)

# SALVANDO
plt.savefig('graficoRSSI.pdf', format='pdf', bbox_inches = 'tight')

# EXIBINDO
plt.plot()
# Out:
# []
